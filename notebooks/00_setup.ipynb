# %%
# Install all the packages required for the whole project
# !pip install pandas numpy scikit-learn xgboost tensorflow shap streamlit plotly matplotlib seaborn optuna joblib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 85.4 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 46.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 127.7 MB/s eta 0:00:0000:01
# ...

# %%
# Create a clean requirements.txt
# !pip freeze > /content/requirements.txt
print("requirements.txt created!")
# Out:
# requirements.txt created!
